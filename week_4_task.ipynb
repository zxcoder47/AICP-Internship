# %% [markdown]
# ### Q.1:Import libraries (Numpy, pandas, matplotlib, plotly and seaborn) and then read csv file.

# %%
# import All the Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly as pl
import seaborn as sns

# %%
# Read the CSV file.
menu_df=pd.read_csv("menu.csv")
# Check the top 10 rows of the dataframe to see if it was read correctly.
menu_df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# ###  Q.2: Check statistical facts by checking all columns. Then calculate the maximum value of the following
#  attributes ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (%
#  Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# %%
# Get the maximum values for the attributes
max_calories = menu_df['Calories'].max()
max_calories_from_fat = menu_df['Calories from Fat'].max()
max_total_fat = menu_df['Total Fat'].max()
max_total_fat_daily_value = menu_df['Total Fat (% Daily Value)'].max()
max_saturated_fat = menu_df['Saturated Fat'].max()
max_saturated_fat_daily_value = menu_df['Saturated Fat (% Daily Value)'].max()
max_trans_fat = menu_df['Trans Fat'].max()
max_cholesterol = menu_df['Cholesterol'].max()
max_cholesterol_daily_value = menu_df['Cholesterol (% Daily Value)'].max()
max_sodium = menu_df['Sodium'].max()
max_sodium_daily_value = menu_df['Sodium (% Daily Value)'].max()
max_carbohydrates = menu_df['Carbohydrates'].max()
max_carbohydrates_daily_value = menu_df['Carbohydrates (% Daily Value)'].max()
max_dietary_fiber = menu_df['Dietary Fiber'].max()
max_dietary_fiber_daily_value = menu_df['Dietary Fiber (% Daily Value)'].max()
max_sugars = menu_df['Sugars'].max()
max_protein = menu_df['Protein'].max()
max_vitamin_a_daily_value = menu_df['Vitamin A (% Daily Value)'].max()
max_vitamin_c_daily_value = menu_df['Vitamin C (% Daily Value)'].max()
max_calcium_daily_value = menu_df['Calcium (% Daily Value)'].max()
max_iron_daily_value = menu_df['Iron (% Daily Value)'].max()

# Print the maximum values
print("Maximum Calories:", max_calories)
print("Maximum Calories from Fat:", max_calories_from_fat)
print("Maximum Total Fat:", max_total_fat)
print("Maximum Total Fat (% Daily Value):", max_total_fat_daily_value)
print("Maximum Saturated Fat:", max_saturated_fat)
print("Maximum Saturated Fat (% Daily Value):", max_saturated_fat_daily_value)
print("Maximum Trans Fat:", max_trans_fat)
print("Maximum Cholesterol:", max_cholesterol)
print("Maximum Cholesterol (% Daily Value):", max_cholesterol_daily_value)
print("Maximum Sodium:", max_sodium)
print("Maximum Sodium (% Daily Value):", max_sodium_daily_value)
print("Maximum Carbohydrates:", max_carbohydrates)
print("Maximum Carbohydrates (% Daily Value):", max_carbohydrates_daily_value)
print("Maximum Dietary Fiber:", max_dietary_fiber)
print("Maximum Dietary Fiber (% Daily Value):", max_dietary_fiber_daily_value)
print("Maximum Sugars:", max_sugars)
print("Maximum Protein:", max_protein)
print("Maximum Vitamin A (% Daily Value):", max_vitamin_a_daily_value)
print("Maximum Vitamin C (% Daily Value):", max_vitamin_c_daily_value)
print("Maximum Calcium (% Daily Value):", max_calcium_daily_value)
print("Maximum Iron (% Daily Value):", max_iron_daily_value)
# Out:
# Maximum Calories: 1880
# Maximum Calories from Fat: 1060
# Maximum Total Fat: 118.0
# Maximum Total Fat (% Daily Value): 182
# Maximum Saturated Fat: 20.0
# Maximum Saturated Fat (% Daily Value): 102
# Maximum Trans Fat: 2.5
# Maximum Cholesterol: 575
# Maximum Cholesterol (% Daily Value): 192
# Maximum Sodium: 3600
# Maximum Sodium (% Daily Value): 150
# Maximum Carbohydrates: 141
# Maximum Carbohydrates (% Daily Value): 47
# Maximum Dietary Fiber: 7
# Maximum Dietary Fiber (% Daily Value): 28
# Maximum Sugars: 128
# Maximum Protein: 87
# Maximum Vitamin A (% Daily Value): 170
# Maximum Vitamin C (% Daily Value): 240
# Maximum Calcium (% Daily Value): 70
# Maximum Iron (% Daily Value): 40

# %% [markdown]
# ### Q.3: Check to see if infact there is any correlation between Calories and other independent variables by plotting a correlation matrix next.

# %%
# Select the relevant columns for the correlation matrix
columns_of_interest = [
    'Calories',
    'Total Fat',
    'Saturated Fat',
    'Cholesterol',
    'Sodium',
    'Carbohydrates',
    'Dietary Fiber',
    'Sugars',
    'Protein',
    'Vitamin A (% Daily Value)',
    'Vitamin C (% Daily Value)',
    'Calcium (% Daily Value)',
    'Iron (% Daily Value)'
]

selected_columns = menu_df[columns_of_interest]

# Calculate the correlation matrix
correlation_matrix = selected_columns.corr()

# Plot the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Q.4: Draw boxplot for Calories vs Category to spot outliers and max calories category

# %%
# Draw the boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='Calories', y='Category',hue="Category", data=menu_df)
plt.title('Calories Distribution by Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###  Q.5: Figure out which exact item contains a high quantity for
#  ['Calories', 'Total Fat', 'Carbohydrates',
#  'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A  (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium
#  (% Daily Value)', 'Iron (% Daily Value)'].

# %%
# Define the attributes of interest
attributes = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars',
              'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
              'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# Find the item with the highest values for the attributes
max_item = menu_df.loc[menu_df[attributes].idxmax()]

# Print the item with the highest values
print("Item with Highest Values:")
print(max_item[['Item'] + attributes])
# Out:
# Item with Highest Values:
#                                               Item  Calories  Total Fat  \
# 82                    Chicken McNuggets (40 piece)      1880      118.0
# 82                    Chicken McNuggets (40 piece)      1880      118.0
# 249                        Chocolate Shake (Large)       850       23.0
# 32     Big Breakfast with Hotcakes (Large Biscuit)      1150       60.0
# 253           McFlurry with M&M’s Candies (Medium)       930       33.0
# 82                    Chicken McNuggets (40 piece)      1880      118.0
# 84     Premium Bacon Ranch Salad (without Chicken)       140        7.0
# 135               Minute Maid Orange Juice (Large)       280        0.0
# 246                       Strawberry Shake (Large)       850       24.0
# 31   Big Breakfast with Hotcakes (Regular Biscuit)      1090       56.0
#
#      Carbohydrates  Dietary Fiber  Sugars  Protein  Vitamin A (% Daily Value)  \
# ...

# %% [markdown]
# ### Q.6: Draw Stripplot for each
#  category against the following
#  attributes ['Calories', 'Total Fat',
#  'Carbohydrates', 'Dietary
#  Fiber', 'Sugars', 'Protein',
#  'Vitamin A (% Daily Value)',
#  'Vitamin C (% Daily Value)',
#  'Calcium (% Daily Value)', 'Iron
#  (% Daily Value)'].

# %%
# Define the attributes of interest
attributes = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars',
              'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
              'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# Draw the stripplot for each attribute
for attribute in attributes:
    plt.figure(figsize=(8, 6))
    sns.stripplot(x='Category', y=attribute,hue="Category", data=menu_df, jitter=True)
    plt.title(f'{attribute} Distribution by Category')
    plt.xlabel('Category')
    plt.ylabel(attribute)
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### Q.7: Draw a horizontal bar graph for items in each category against the calories.
# Here is one sample for all items in Beef & Pork, you have to do it for items in each category. Also, write
#  your observation.

# %%
# Select the relevant columns
category_calories_df = menu_df[['Category', 'Item', 'Calories']]

# Group the data by category and calculate the average calories for each item in the category
category_avg_calories_df = category_calories_df.groupby(['Category', 'Item']).mean().reset_index()

# Sort the data by calories in descending order within each category
category_avg_calories_df.sort_values(['Category', 'Calories'], ascending=[True, False], inplace=True)

# Set up the figure and axes
plt.figure(figsize=(10, 8))
ax = sns.barplot(x='Calories', y='Item', hue='Category', data=category_avg_calories_df, dodge=False)

# Set the x-axis label
plt.xlabel('Calories')

# Set the y-axis label
plt.ylabel('Item')

# Set the title
plt.title('Average Calories of Items in Each Category')

# Show the legend
plt.legend(title='Category')

# Show the plot
plt.show()

# %% [markdown]
# **Observation:** By examining the horizontal bar graph, you can observe the relative average calorie content of items within each category. The graph allows for easy visual comparison of the calorie levels across different items in the same category. You can identify the items with higher or lower average calories within each category based on the length of the bars.
